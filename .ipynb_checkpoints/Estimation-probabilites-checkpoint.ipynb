# %% [markdown]
# # Calcul approché des probabilités par simulation

# %% [markdown]
# ## 1 Introduction

# %% [markdown]
# (à faire)

# %%
import random
def jet2d():
    de1 = random.choice([1,2,3,4,5,6])
    de2 = random.choice([1,2,3,4,5,6])
    return (de1,de2)
realisation = jet2d()
print(realisation)
# Out:
# (4, 3)

# %%
def testA(des):
    d1 = des[0]
    d2 = des[1]
    res = (d1 == d2 or d2 == d1 + 1 or d1 == d2+1)
    return res

resTest = testA(realisation)

print(resTest)
# Out:
# True

# %%
compteur = 0
for i in range(1000):
    res = testA(jet2d())
    if res == True :
        compteur += 1
print("Estimation de la probabilité : {}".format(compteur/1000))
# Out:
# Estimation de la probabilité : 0.473

# %% [markdown]
# ## 2 Exercices pratiques

# %% [markdown]
# ### 2.1 Travaux préliminaires

# %% [markdown]
# #### 2.1.1 Simulation répétée de l’expérience

# %%
def simulrepExemple(n: int) -> float:
    compteur = 0
    for i in range(n):
        res = testA(jet2d())
        if res == True :
            compteur += 1
    return compteur/n

# %%
print(simulrepExemple(10))
print(simulrepExemple(100))
print(simulrepExemple(1000))
print(simulrepExemple(10000))
# Out:
# 0.1
# 0.53
# 0.464
# 0.4402

# %% [markdown]
# #### 2.1.2 Convergence

# %%
def convergence(nmax: int) -> list:
    proba = []
    compteur = 0
    n = 0
    for i in range(nmax):
        n += 1
        res = testA(jet2d())
        if res == True :
            compteur += 1
        proba += [compteur/(n)]
    print(proba)
    return proba

# %%
import matplotlib.pyplot as plt
N = 1000
x = list(range(1,N+1))
y = convergence(N)
plt.figure()
plt.plot(x,y)
plt.xlabel("Nombre de répétitions")
plt.ylabel("Probabilité estimée")
plt.title("Évolution de l'estimation de la probabilité en fonction du nombre de répétitions de l'expérience aléatoire")
plt.show()
# Out:
# [0.0, 0.5, 0.6666666666666666, 0.5, 0.4, 0.5, 0.42857142857142855, 0.5, 0.4444444444444444, 0.5, 0.45454545454545453, 0.4166666666666667, 0.38461538461538464, 0.42857142857142855, 0.4666666666666667, 0.4375, 0.4117647058823529, 0.3888888888888889, 0.3684210526315789, 0.35, 0.3333333333333333, 0.36363636363636365, 0.391304347826087, 0.4166666666666667, 0.4, 0.4230769230769231, 0.4444444444444444, 0.4642857142857143, 0.4827586206896552, 0.5, 0.5161290322580645, 0.53125, 0.5454545454545454, 0.5588235294117647, 0.5428571428571428, 0.5277777777777778, 0.5135135135135135, 0.5263157894736842, 0.5128205128205128, 0.5, 0.5121951219512195, 0.5, 0.5116279069767442, 0.5, 0.4888888888888889, 0.5, 0.5106382978723404, 0.5, 0.4897959183673469, 0.5, 0.5098039215686274, 0.5192307692307693, 0.5283018867924528, 0.5370370370370371, 0.5272727272727272
.4824120603015075, 0.485, 0.48258706467661694, 0.4801980198019802, 0.4827586206896552, 0.4852941176470588, 0.4878048780487805, 0.49029126213592233, 0.48792270531400966, 0.4855769230769231, 0.4880382775119617, 0.49047619047619045, 0.4881516587677725, 0.49056603773584906, 0.48826291079812206, 0.49065420560747663, 0.4883720930232558, 0.49074074074074076, 0.4930875576036866, 0.4954128440366973, 0.4931506849315068, 0.4954545454545455, 0.49321266968325794, 0.49099099099099097, 0.493273 ...

# %% [markdown]
# ### 2.2 Chapeaux dérangés

# %%
import itertools, random
def chapeauchapeau(n: int, nrep: int) -> float:
    nb_iss_fav = 0
    for i in range(nrep):
        issues = random.sample(range(1, n), n-1)
        k = 0
        for i in range(len(issues)):
            if issues[i] == i:
                k += 1
        if k == 0:
            nb_iss_fav += 1
    return nb_iss_fav / nrep

# %%
import random
print(random.sample([1, 2, 3, 4], 4))
# Out:
# [1, 2, 3, 4]

# %%
print(chapeauchapeau(6, 10000))
# Out:
# 0.4423

# %% [markdown]
# ### 2.3 Jeu de dés

# %%
def desmultiples() -> float:
    nb_iss_fav = 0
    issues = random.sample(range(1, 120), 4)
    print(issues)
    mult21 = 0
    mult9 = 0
        
    for j in range(len(issues)):
        if (issues[j] % 21 == 0):
            mult21 += 1
        if (issues[j] % 9 == 0):
            mult9 += 1
    if (mult21 >= 1) or (mult9 >= 2):
        nb_iss_fav += 1
    return nb_iss_fav / 4

# %%
print(desmultiples())
# Out:
# [30, 90, 97, 79]
# 0.0

# %%
def despaires() -> float:
    nb_iss_fav = 0
    issues = random.sample(range(1, 120), 4)
    print(issues)
    issues.sort()
        
    if ((issues[0] == issues[1]) and (issues[2] == issues[3])):
        nb_iss_fav += 1
    return nb_iss_fav / 4

# %%
print(despaires())
# Out:
# [119, 36, 68, 105]
# 0.0

# %% [markdown]
# ### 2.4 « Paradoxe » des anniversaires

# %%
def tirage(n: int) -> list:
    return list(range(1, n+1))

# %%
def test(x: list) -> bool:
    x.sort()
    res = False
    for i in range(len(x)-1):
        if x[i] == x[i+1]:
            res = True
    return res

# %%
def probA(n: int, nrep: int) -> float:
    count = 0
    for i in range(nrep):
        experience = tirage(n)
        if test(experience) == True:
            count += 1
    return count / nrep

# %%
print(probA(n = 10, nrep = 1000))
# Out:
# 0.0

# %%
print(probA(n = 21, nrep = 1000))
# Out:
# 0.0

# %% [markdown]
# #### 2.4.1 Estimation de pi

# %%
import random
def pointCarre(nrep: int) -> float:
    count = 0
    for i in range(nrep):
        experience = (round(random.random(), 1), round(random.random(), 1))
        if (((experience[0]**2) + (experience[1]**2)) <= 1):
            count += 1
    return count / nrep

# %%
print(pointCarre(1000))
# Out:
# 0.802
